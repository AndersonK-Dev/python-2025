# %% [markdown]
# <a href="https://colab.research.google.com/github/crodriguezn/python-2025/blob/master/U2_Tema_3_Manejo_de_Archivos_y_Excepciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Escribir un archivo

# %%
with open("ejemplo.txt", "w") as archivo:
    archivo.write("Hola, este es un archivo de ejemplo.\n")
    archivo.write("Segunda línea.\n")

# %% [markdown]
# # Leer archivo

# %%
with open("ejemplo.txt", "r") as archivo:
    contenido = archivo.read()
    print("Contenido del archivo:")
    print(contenido)
# Out:
# Contenido del archivo:
# Hola, este es un archivo de ejemplo.
# Segunda línea.

# %% [markdown]
# # Manejo de excepciones

# %%
try:
    numero = int(input("Ingresa un número: "))
    print("Número ingresado:", numero)
except ValueError:
    print("Error: Debes ingresar un número válido.")
# Out:
# Error: Debes ingresar un número válido.

# %%
try:
    with open("archivo_inexistente.txt", "r") as f:
        print(f.read())
except FileNotFoundError:
    print("El archivo no existe.")
# Out:
# Hola, este es un archivo de ejemplo.
# Segunda línea.
