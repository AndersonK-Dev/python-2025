# %% [markdown]
# <a href="https://colab.research.google.com/github/crodriguezn/python-2025/blob/master/U2_Tema_2_Funciones_y_Programaci%C3%B3n_Modular.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Función Básica

# %%
def saludar(nombre):
    return f"Hola, {nombre}!"

print(saludar("Carlos"))
# Out:
# Hola, Carlos!

# %% [markdown]
# # Función con múltiples parámetros

# %%
def area_rectangulo(base, altura):
    return base * altura

print("Área del rectángulo:", area_rectangulo(5, 3))
# Out:
# Área del rectángulo: 15

# %% [markdown]
# # Función con valor por defecto

# %%
def potencia(base, exponente=2):
    return base ** exponente

print("Potencia:", potencia(3))
print("Potencia con exponente 3:", potencia(4, 3))
# Out:
# Potencia: 9
# Potencia con exponente 3: 27

# %% [markdown]
# # Usando módulos

# %%
import math
from math import pi
print("Raíz cuadrada de 16:", math.sqrt(16))
print("Valor de pi:", pi)
# Out:
# Raíz cuadrada de 16: 4.0
